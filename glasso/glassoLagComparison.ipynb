# %%
# ============================================================
# COMPARE GLASSO STATE GRAPH RESULTS ACROSS MULTIPLE LAGS
# input : saved outputs from lag-specific folders
# output: structured comparison report printed in notebook
# ============================================================

import os
import json
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd


# ============================================================
# CONFIG
# ============================================================

RUNS = {
    "lag_3":  "./glasso_cache_v4_lag3",
    "lag_10": "./glasso_cache_v4_lag10",
    "lag_20": "./glasso_cache_v4_lag20",
}

TOP_N = 10
FLOAT_FMT = "{:.6f}"


# ============================================================
# UTILS
# ============================================================

def print_rule(char="=", width=100):
    print(char * width)


def print_section(title):
    print()
    print_rule("=")
    print(title)
    print_rule("=")


def print_subsection(title):
    print()
    print_rule("-")
    print(title)
    print_rule("-")


def load_json(path):
    if not os.path.exists(path):
        print(f"[WARNING] Missing JSON: {path}")
        return {}
    with open(path, "r") as f:
        return json.load(f)


def load_csv(path):
    if not os.path.exists(path):
        print(f"[WARNING] Missing CSV: {path}")
        return pd.DataFrame()
    return pd.read_csv(path)


def fmt_df(df, n=None):
    if df.empty:
        print("[empty]")
        return
    if n is not None:
        df = df.head(n)
    print(df.to_string(index=False))


def safe_get(d, key, default=np.nan):
    return d.get(key, default)


def run_paths(base_dir):
    return {
        "summary_json": os.path.join(
            base_dir, "state_graph_final", "lob_state_glasso_summary.json"
        ),
        "edge_analysis_json": os.path.join(
            base_dir, "state_graph_edge_analysis", "lob_state_edge_analysis_summary.json"
        ),
        "ranking_summary_json": os.path.join(
            base_dir, "state_graph_edge_rankings", "lob_state_edge_rankings_summary.json"
        ),
        "summary_by_lag_type": os.path.join(
            base_dir, "state_graph_edge_analysis", "summary_by_lag_type.csv"
        ),
        "summary_by_level_relation": os.path.join(
            base_dir, "state_graph_edge_analysis", "summary_by_level_relation.csv"
        ),
        "summary_by_feature_pair": os.path.join(
            base_dir, "state_graph_edge_analysis", "summary_by_feature_pair.csv"
        ),
        "summary_by_side_pair": os.path.join(
            base_dir, "state_graph_edge_analysis", "summary_by_side_pair.csv"
        ),
        "top_edges": os.path.join(
            base_dir, "state_graph_edge_rankings", "top_edges_overall.csv"
        ),
        "top_cross_lag": os.path.join(
            base_dir, "state_graph_edge_rankings", "top_edges_cross_lag.csv"
        ),
        "top_intra_lag": os.path.join(
            base_dir, "state_graph_edge_rankings", "top_edges_intra_lag.csv"
        ),
    }


def add_run_col(df, run_name):
    if df.empty:
        return df
    out = df.copy()
    out.insert(0, "run", run_name)
    return out


# ============================================================
# LOAD ALL RUNS
# ============================================================

all_data = {}

for run_name, base_dir in RUNS.items():
    paths = run_paths(base_dir)

    all_data[run_name] = {
        "base_dir": base_dir,
        "paths": paths,
        "summary": load_json(paths["summary_json"]),
        "edge_analysis": load_json(paths["edge_analysis_json"]),
        "ranking_summary": load_json(paths["ranking_summary_json"]),
        "summary_by_lag_type": load_csv(paths["summary_by_lag_type"]),
        "summary_by_level_relation": load_csv(paths["summary_by_level_relation"]),
        "summary_by_feature_pair": load_csv(paths["summary_by_feature_pair"]),
        "summary_by_side_pair": load_csv(paths["summary_by_side_pair"]),
        "top_edges": load_csv(paths["top_edges"]),
        "top_cross_lag": load_csv(paths["top_cross_lag"]),
        "top_intra_lag": load_csv(paths["top_intra_lag"]),
    }


# ============================================================
# 1) GLOBAL COMPARISON TABLE
# ============================================================

rows = []

for run_name, data in all_data.items():
    s = data["summary"]
    e = data["edge_analysis"]

    row = {
        "run": run_name,
        "base_dir": data["base_dir"],

        "best_alpha": safe_get(s, "best_alpha"),
        "fit_time_sec": safe_get(s, "fit_time_sec"),
        "n_samples": safe_get(s, "n_samples"),
        "n_features": safe_get(s, "n_features"),
        "n_possible_edges": safe_get(s, "n_possible_edges"),
        "n_edges": safe_get(s, "n_edges"),
        "graph_density": safe_get(s, "graph_density"),

        "share_intra_lag": safe_get(e, "share_intra_lag"),
        "share_cross_lag": safe_get(e, "share_cross_lag"),
        "share_same_level": safe_get(e, "share_same_level"),
        "share_adjacent_level": safe_get(e, "share_adjacent_level"),
        "share_distant_level": safe_get(e, "share_distant_level"),
        "share_global_level": safe_get(e, "share_global_level"),
        "share_touches_lag0": safe_get(e, "share_touches_lag0"),

        "mean_abs_precision_weight": safe_get(e, "mean_abs_precision_weight"),
        "median_abs_precision_weight": safe_get(e, "median_abs_precision_weight"),
        "max_abs_precision_weight": safe_get(e, "max_abs_precision_weight"),
        "mean_abs_partial_corr_weight": safe_get(e, "mean_abs_partial_corr_weight"),
        "median_abs_partial_corr_weight": safe_get(e, "median_abs_partial_corr_weight"),
        "max_abs_partial_corr_weight": safe_get(e, "max_abs_partial_corr_weight"),
    }

    rows.append(row)

global_compare = pd.DataFrame(rows)


# ============================================================
# 2) CATEGORY COMPARISON TABLES
# ============================================================

lag_type_compare = pd.concat(
    [
        add_run_col(data["summary_by_lag_type"], run_name)
        for run_name, data in all_data.items()
        if not data["summary_by_lag_type"].empty
    ],
    ignore_index=True,
)

level_relation_compare = pd.concat(
    [
        add_run_col(data["summary_by_level_relation"], run_name)
        for run_name, data in all_data.items()
        if not data["summary_by_level_relation"].empty
    ],
    ignore_index=True,
)

feature_pair_compare = pd.concat(
    [
        add_run_col(data["summary_by_feature_pair"], run_name)
        for run_name, data in all_data.items()
        if not data["summary_by_feature_pair"].empty
    ],
    ignore_index=True,
)

side_pair_compare = pd.concat(
    [
        add_run_col(data["summary_by_side_pair"], run_name)
        for run_name, data in all_data.items()
        if not data["summary_by_side_pair"].empty
    ],
    ignore_index=True,
)


# ============================================================
# 3) PIVOT TABLES FOR EASY COMPARISON
# ============================================================

def pivot_metric(df, index_col, value_col):
    if df.empty or index_col not in df.columns or value_col not in df.columns:
        return pd.DataFrame()

    return (
        df.pivot_table(
            index=index_col,
            columns="run",
            values=value_col,
            aggfunc="first",
        )
        .reset_index()
    )


lag_share_pivot = pivot_metric(lag_type_compare, "lag_relation", "share_edges")
level_share_pivot = pivot_metric(level_relation_compare, "level_relation", "share_edges")
feature_pair_share_pivot = pivot_metric(feature_pair_compare, "feature_pair", "share_edges")
side_pair_share_pivot = pivot_metric(side_pair_compare, "side_pair", "share_edges")


# ============================================================
# 4) TOP EDGE COMPARISON
# ============================================================

top_edges_compare = pd.concat(
    [
        add_run_col(data["top_edges"], run_name)
        for run_name, data in all_data.items()
        if not data["top_edges"].empty
    ],
    ignore_index=True,
)

top_cross_lag_compare = pd.concat(
    [
        add_run_col(data["top_cross_lag"], run_name)
        for run_name, data in all_data.items()
        if not data["top_cross_lag"].empty
    ],
    ignore_index=True,
)

top_intra_lag_compare = pd.concat(
    [
        add_run_col(data["top_intra_lag"], run_name)
        for run_name, data in all_data.items()
        if not data["top_intra_lag"].empty
    ],
    ignore_index=True,
)


# ============================================================
# 5) PRINT REPORT
# ============================================================

print_section("GLASSO STATE GRAPH - LAG COMPARISON REPORT")

print_subsection("1) GLOBAL OVERVIEW")
cols_global = [
    "run",
    "best_alpha",
    "fit_time_sec",
    "n_features",
    "n_edges",
    "graph_density",
    "share_cross_lag",
    "share_same_level",
    "share_adjacent_level",
    "share_global_level",
    "share_touches_lag0",
    "median_abs_precision_weight",
    "max_abs_precision_weight",
]
fmt_df(global_compare[cols_global])

print_subsection("2) FULL GLOBAL METRICS")
fmt_df(global_compare.drop(columns=["base_dir"], errors="ignore"))

print_subsection("3) SHARE BY LAG TYPE")
fmt_df(lag_share_pivot)

print_subsection("4) SHARE BY LEVEL RELATION")
fmt_df(level_share_pivot)

print_subsection("5) SHARE BY SIDE PAIR")
fmt_df(side_pair_share_pivot)

print_subsection("6) TOP FEATURE PAIRS BY RUN")
for run_name in RUNS.keys():
    print()
    print(f"--- {run_name} ---")
    df = feature_pair_compare[feature_pair_compare["run"] == run_name].copy()
    if df.empty:
        print("[empty]")
    else:
        df = df.sort_values("share_edges", ascending=False)
        fmt_df(
            df[
                [
                    "feature_pair",
                    "n_edges",
                    "share_edges",
                    "mean_abs_precision_weight",
                    "median_abs_precision_weight",
                    "max_abs_precision_weight",
                    "mean_abs_partial_corr_weight",
                    "max_abs_partial_corr_weight",
                ]
            ],
            n=TOP_N,
        )

print_subsection("7) TOP OVERALL EDGES BY RUN")
for run_name in RUNS.keys():
    print()
    print(f"--- {run_name} ---")
    df = top_edges_compare[top_edges_compare["run"] == run_name].copy()
    if df.empty:
        print("[empty]")
    else:
        cols = [
            "rank",
            "source",
            "target",
            "abs_precision_weight",
            "partial_corr_weight",
            "sign",
            "lag_relation",
            "level_relation",
            "feature_pair",
            "side_pair",
            "feature_type_pair",
        ]
        cols = [c for c in cols if c in df.columns]
        fmt_df(df[cols], n=TOP_N)

print_subsection("8) TOP CROSS-LAG EDGES BY RUN")
for run_name in RUNS.keys():
    print()
    print(f"--- {run_name} ---")
    df = top_cross_lag_compare[top_cross_lag_compare["run"] == run_name].copy()
    if df.empty:
        print("[empty]")
    else:
        cols = [
            "rank",
            "source",
            "target",
            "abs_precision_weight",
            "partial_corr_weight",
            "lag_relation",
            "level_relation",
            "feature_pair",
            "side_pair",
        ]
        cols = [c for c in cols if c in df.columns]
        fmt_df(df[cols], n=TOP_N)

print_subsection("9) TOP INTRA-LAG EDGES BY RUN")
for run_name in RUNS.keys():
    print()
    print(f"--- {run_name} ---")
    df = top_intra_lag_compare[top_intra_lag_compare["run"] == run_name].copy()
    if df.empty:
        print("[empty]")
    else:
        cols = [
            "rank",
            "source",
            "target",
            "abs_precision_weight",
            "partial_corr_weight",
            "lag_relation",
            "level_relation",
            "feature_pair",
            "side_pair",
        ]
        cols = [c for c in cols if c in df.columns]
        fmt_df(df[cols], n=TOP_N)


# ============================================================
# 6) AUTOMATIC INTERPRETATION
# ============================================================

print_subsection("10) COMPACT AUTOMATIC INTERPRETATION")

best_fit = global_compare.sort_values("fit_time_sec").iloc[0]
most_edges = global_compare.sort_values("n_edges", ascending=False).iloc[0]
highest_cross_lag = global_compare.sort_values("share_cross_lag", ascending=False).iloc[0]
highest_global = global_compare.sort_values("share_global_level", ascending=False).iloc[0]
highest_same_level = global_compare.sort_values("share_same_level", ascending=False).iloc[0]

print(f"- Fastest run              : {best_fit['run']} ({best_fit['fit_time_sec']:.2f} sec)")
print(f"- Most connected graph     : {most_edges['run']} ({int(most_edges['n_edges'])} edges)")
print(f"- Strongest temporal graph : {highest_cross_lag['run']} (cross-lag share={highest_cross_lag['share_cross_lag']:.4f})")
print(f"- Most global-driven graph : {highest_global['run']} (global-level share={highest_global['share_global_level']:.4f})")
print(f"- Most local-level graph   : {highest_same_level['run']} (same-level share={highest_same_level['share_same_level']:.4f})")

print()
print("Suggested reading:")
print("- lag_3  : compact baseline, easier to interpret")
print("- lag_10 : balanced compromise between temporal richness and readability")
print("- lag_20 : long-memory experiment, richer but more autoregressive and heavier")

print()
print_rule("=")
print("END OF COMPARISON REPORT")
print_rule("=")
# Out:
# ====================================================================================================
# GLASSO STATE GRAPH - LAG COMPARISON REPORT
# ====================================================================================================
#
# ----------------------------------------------------------------------------------------------------
# 1) GLOBAL OVERVIEW
# ----------------------------------------------------------------------------------------------------
#    run  best_alpha  fit_time_sec  n_features  n_edges  graph_density  share_cross_lag  share_same_level  share_adjacent_level  share_global_level  share_touches_lag0  median_abs_precision_weight  max_abs_precision_weight
#  lag_3         0.2      0.954664          98      428       0.090048         0.789720          0.280374              0.004673            0.714953            0.448598                     0.026512                  2.190752
# lag_10         0.2     31.544974         266     2302       0.065314         0.899218          0.416160              0.032146            0.551694            0.185491                     0.024305                  2.188716
# lag_20         0.2    126.930654         506     5419       0.042414         0.921019          0.487728              0.064403            0.447869            0.107584                     0.027614                  2.186626
#
# ----------------------------------------------------------------------------------------------------
# 2) FULL GLOBAL METRICS
# ----------------------------------------------------------------------------------------------------
#    run  best_alpha  fit_time_sec  n_samples  n_features  n_possible_edges  n_edges  graph_density  share_intra_lag  share_cross_lag  share_same_level  share_adjacent_level  share_distant_level  share_global_level  share_touches_lag0  mean_abs_precision_weight  median_abs_precision_weight  max_abs_precision_weight  mean_abs_partial_corr_weight  median_abs_partial_corr_weight  max_abs_partial_corr_weight
#  lag_3         0.2      0.954664     400388          98              4753      428       0.090048         0.210280         0.789720          0.280374              0.004673                  0.0            0.714953            0.448598                   0.225496                     0.026512                  2.190752                      0.097715                        0.010406                     0.786805
# lag_10         0.2     31.544974     400381         266             35245     2302       0.065314         0.100782         0.899218          0.416160              0.032146                  0.0            0.551694            0.185491                   0.133349                     0.024305                  2.188716                      0.053873                        0.010520                     0.785203
# lag_20         0.2    126.930654     400371         506            127765     5419       0.042414         0.078981         0.921019          0.487728              0.064403                  0.0            0.447869            0.107584                   0.112062                     0.027614                  2.186626                      0.044618                        0.010370                     0.783987
#
# ----------------------------------------------------------------------------------------------------
# 3) SHARE BY LAG TYPE
# ----------------------------------------------------------------------------------------------------
#  lag_relation   lag_10   lag_20    lag_3
#   cross_lag_1 0.224587 0.172172 0.413551
# cross_lag_gt1 0.674631 0.748847 0.376168
#     intra_lag 0.100782 0.078981 0.210280
#
# ----------------------------------------------------------------------------------------------------
# 4) SHARE BY LEVEL RELATION
# ----------------------------------------------------------------------------------------------------
# level_relation   lag_10   lag_20    lag_3
# adjacent_level 0.032146 0.064403 0.004673
#   global_level 0.551694 0.447869 0.714953
#     same_level 0.416160 0.487728 0.280374
#
# ----------------------------------------------------------------------------------------------------
# 5) SHARE BY SIDE PAIR
# ----------------------------------------------------------------------------------------------------
#     side_pair   lag_10   lag_20    lag_3
#       ask|ask 0.444396 0.432183 0.467290
#       ask|bid      NaN 0.002953      NaN
#    ask|global 0.004778 0.003875 0.009346
#       bid|bid 0.488271 0.472227 0.464953
#    bid|global 0.009991 0.007935 0.021028
# global|global 0.052563 0.080827 0.037383
#
# ----------------------------------------------------------------------------------------------------
# 6) TOP FEATURE PAIRS BY RUN
# ----------------------------------------------------------------------------------------------------
#
# --- lag_3 ---
#                      feature_pair  n_edges  share_edges  mean_abs_precision_weight  median_abs_precision_weight  max_abs_precision_weight  mean_abs_partial_corr_weight  max_abs_partial_corr_weight
#              bids|depth_bid_total      133     0.310748                   0.017602                     0.012988                  0.095367                      0.006353                     0.037595
#              asks|depth_ask_total      132     0.308411                   0.023739                     0.017672                  0.111557                      0.009965                     0.051570
#                         asks|asks       62     0.144860                   0.424798                     0.402874                  1.096897                      0.240487                     0.442785
#                         bids|bids       60     0.140187                   0.623661                     0.716990                  1.201808                      0.275209                     0.436949
#   depth_bid_total|depth_bid_total        6     0.014019                   1.026932                     1.018007                  1.131820                      0.288060                     0.317627
# global_imbalance|global_imbalance        6     0.014019                   0.982710                     0.971700                  1.121215                      0.285378                     0.326080
#   depth_ask_total|depth_ask_total        6     0.014019                   0.955950                     0.948371                  1.079193                      0.278413                     0.314155
#                     spread|spread        6     0.014019                   0.902422                     0.882473                  1.110114                      0.296622                     0.365696
#  depth_ask_total|global_imbalance        4     0.009346                   0.213094                     0.212769                  0.224115                      0.062114                     0.066969
#  depth_bid_total|global_imbalance        4     0.009346                   0.178443                     0.178642                  0.185523                      0.051023                     0.054204
#
# --- lag_10 ---
#                      feature_pair  n_edges  share_edges  mean_abs_precision_weight  median_abs_precision_weight  max_abs_precision_weight  mean_abs_partial_corr_weight  max_abs_partial_corr_weight
#                         bids|bids      544     0.236316                   0.229821                     0.095331                  1.022224                      0.093282                     0.415818
#              bids|depth_bid_total      525     0.228063                   0.006078                     0.003135                  0.070710                      0.002008                     0.026483
#                         asks|asks      488     0.211990                   0.186646                     0.091117                  1.058930                      0.098696                     0.419792
#              asks|depth_ask_total      480     0.208514                   0.009843                     0.004985                  0.084444                      0.003801                     0.037208
#   depth_bid_total|depth_bid_total       55     0.023892                   0.380669                     0.348855                  0.796557                      0.094853                     0.204988
# global_imbalance|global_imbalance       55     0.023892                   0.362664                     0.319014                  0.879751                      0.094490                     0.239459
#   depth_ask_total|depth_ask_total       55     0.023892                   0.359743                     0.307224                  0.813819                      0.093663                     0.219788
#                     spread|spread       55     0.023892                   0.324460                     0.255731                  0.959442                      0.095791                     0.300846
#  depth_ask_total|global_imbalance       11     0.004778                   0.094264                     0.091853                  0.124823                      0.024735                     0.034667
#  depth_bid_total|global_imbalance       11     0.004778                   0.077858                     0.074912                  0.101221                      0.019972                     0.027396
#
# --- lag_20 ---
#                      feature_pair  n_edges  share_edges  mean_abs_precision_weight  median_abs_precision_weight  max_abs_precision_weight  mean_abs_partial_corr_weight  max_abs_partial_corr_weight
#                         bids|bids     1581     0.291751                   0.158699                     0.050930                  1.018659                      0.063213                     0.415839
#                         asks|asks     1411     0.260380                   0.130804                     0.037325                  1.058974                      0.068081                     0.419524
#              bids|depth_bid_total      768     0.141724                   0.005131                     0.002955                  0.064958                      0.001667                     0.024233
#              asks|depth_ask_total      721     0.133050                   0.008658                     0.004781                  0.079257                      0.003290                     0.034762
#   depth_bid_total|depth_bid_total      210     0.038753                   0.199049                     0.121628                  0.768500                      0.048442                     0.196218
# global_imbalance|global_imbalance      210     0.038753                   0.190786                     0.108075                  0.866638                      0.048387                     0.234260
#   depth_ask_total|depth_ask_total      210     0.038753                   0.188211                     0.111543                  0.797160                      0.047964                     0.212659
#                     spread|spread      207     0.038199                   0.171508                     0.083037                  0.958269                      0.049587                     0.300270
#  depth_ask_total|global_imbalance       21     0.003875                   0.055791                     0.048108                  0.095945                      0.014337                     0.026460
#  depth_bid_total|global_imbalance       21     0.003875                   0.045568                     0.040792                  0.081459                      0.011451                     0.021893
#
# ----------------------------------------------------------------------------------------------------
# 7) TOP OVERALL EDGES BY RUN
# ----------------------------------------------------------------------------------------------------
#
# --- lag_3 ---
#  rank                 source                 target  abs_precision_weight  partial_corr_weight     sign lag_relation level_relation                      feature_pair     side_pair feature_type_pair
#     1        mid_price_lag_0           bidp_9_lag_1              2.190752             0.786805 positive  cross_lag_1   global_level                    bidp|mid_price    bid|global      global|level
#     2           bids_0_lag_2           bids_0_lag_3              1.201808             0.358910 positive  cross_lag_1     same_level                         bids|bids       bid|bid       level|level
#     3           bids_0_lag_0           bids_0_lag_1              1.198144             0.357041 positive  cross_lag_1     same_level                         bids|bids       bid|bid       level|level
#     4  depth_bid_total_lag_2  depth_bid_total_lag_3              1.131820             0.317627 positive  cross_lag_1   global_level   depth_bid_total|depth_bid_total       bid|bid     global|global
#     5  depth_bid_total_lag_0  depth_bid_total_lag_1              1.131741             0.317617 positive  cross_lag_1   global_level   depth_bid_total|depth_bid_total       bid|bid     global|global
#     6 global_imbalance_lag_0 global_imbalance_lag_1              1.121215             0.326080 positive  cross_lag_1   global_level global_imbalance|global_imbalance global|global     global|global
#     7 global_imbalance_lag_2 global_imbalance_lag_3              1.120875             0.325619 positive  cross_lag_1   global_level global_imbalance|global_imbalance global|global     global|global
#     8           spread_lag_2           spread_lag_3              1.110114             0.365696 positive  cross_lag_1   global_level                     spread|spread global|global     global|global
#     9           spread_lag_0           spread_lag_1              1.109039             0.365522 positive  cross_lag_1   global_level                     spread|spread global|global     global|global
#    10           asks_0_lag_2           asks_0_lag_3              1.096897             0.442785 positive  cross_lag_1     same_level                         asks|asks       ask|ask       level|level
#
# --- lag_10 ---
#  rank          source        target  abs_precision_weight  partial_corr_weight     sign lag_relation level_relation   feature_pair     side_pair feature_type_pair
#     1 mid_price_lag_0  bidp_9_lag_1              2.188716             0.785203 positive  cross_lag_1   global_level bidp|mid_price    bid|global      global|level
#     2    asks_0_lag_0  asks_0_lag_1              1.058930             0.419792 positive  cross_lag_1     same_level      asks|asks       ask|ask       level|level
#     3    asks_0_lag_9 asks_0_lag_10              1.058865             0.419660 positive  cross_lag_1     same_level      asks|asks       ask|ask       level|level
#     4    bids_1_lag_0  bids_1_lag_1              1.022224             0.404581 positive  cross_lag_1     same_level      bids|bids       bid|bid       level|level
#     5    bids_1_lag_9 bids_1_lag_10              1.019630             0.404134 positive  cross_lag_1     same_level      bids|bids       bid|bid       level|level
#     6    bids_0_lag_9 bids_0_lag_10              1.017186             0.287464 positive  cross_lag_1     same_level      bids|bids       bid|bid       level|level
#     7    bids_0_lag_0  bids_0_lag_1              1.007597             0.283956 positive  cross_lag_1     same_level      bids|bids       bid|bid       level|level
#     8    spread_lag_9 spread_lag_10              0.959442             0.300846 positive  cross_lag_1   global_level  spread|spread global|global     global|global
#     9    spread_lag_0  spread_lag_1              0.957614             0.300249 positive  cross_lag_1   global_level  spread|spread global|global     global|global
#    10    bids_2_lag_0  bids_2_lag_1              0.901021             0.415818 positive  cross_lag_1     same_level      bids|bids       bid|bid       level|level
#
# --- lag_20 ---
#  rank          source        target  abs_precision_weight  partial_corr_weight     sign lag_relation level_relation   feature_pair     side_pair feature_type_pair
#     1 mid_price_lag_0  bidp_9_lag_1              2.186626             0.783987 positive  cross_lag_1   global_level bidp|mid_price    bid|global      global|level
#     2   asks_0_lag_19 asks_0_lag_20              1.058974             0.419524 positive  cross_lag_1     same_level      asks|asks       ask|ask       level|level
#     3    asks_0_lag_0  asks_0_lag_1              1.058728             0.419346 positive  cross_lag_1     same_level      asks|asks       ask|ask       level|level
#     4    bids_1_lag_0  bids_1_lag_1              1.018659             0.402463 positive  cross_lag_1     same_level      bids|bids       bid|bid       level|level
#     5   bids_1_lag_19 bids_1_lag_20              1.018082             0.403461 positive  cross_lag_1     same_level      bids|bids       bid|bid       level|level
#     6    bids_0_lag_0  bids_0_lag_1              1.010897             0.284941 positive  cross_lag_1     same_level      bids|bids       bid|bid       level|level
#     7   bids_0_lag_19 bids_0_lag_20              1.007515             0.283809 positive  cross_lag_1     same_level      bids|bids       bid|bid       level|level
#     8    spread_lag_0  spread_lag_1              0.958269             0.300270 positive  cross_lag_1   global_level  spread|spread global|global     global|global
#     9   spread_lag_19 spread_lag_20              0.951759             0.298656 positive  cross_lag_1   global_level  spread|spread global|global     global|global
#    10    bids_2_lag_0  bids_2_lag_1              0.901044             0.415839 positive  cross_lag_1     same_level      bids|bids       bid|bid       level|level
#
# ----------------------------------------------------------------------------------------------------
# 8) TOP CROSS-LAG EDGES BY RUN
# ----------------------------------------------------------------------------------------------------
#
# --- lag_3 ---
#  rank                 source                 target  abs_precision_weight  partial_corr_weight lag_relation level_relation                      feature_pair     side_pair
#     1        mid_price_lag_0           bidp_9_lag_1              2.190752             0.786805  cross_lag_1   global_level                    bidp|mid_price    bid|global
#     2           bids_0_lag_2           bids_0_lag_3              1.201808             0.358910  cross_lag_1     same_level                         bids|bids       bid|bid
#     3           bids_0_lag_0           bids_0_lag_1              1.198144             0.357041  cross_lag_1     same_level                         bids|bids       bid|bid
#     4  depth_bid_total_lag_2  depth_bid_total_lag_3              1.131820             0.317627  cross_lag_1   global_level   depth_bid_total|depth_bid_total       bid|bid
#     5  depth_bid_total_lag_0  depth_bid_total_lag_1              1.131741             0.317617  cross_lag_1   global_level   depth_bid_total|depth_bid_total       bid|bid
#     6 global_imbalance_lag_0 global_imbalance_lag_1              1.121215             0.326080  cross_lag_1   global_level global_imbalance|global_imbalance global|global
#     7 global_imbalance_lag_2 global_imbalance_lag_3              1.120875             0.325619  cross_lag_1   global_level global_imbalance|global_imbalance global|global
#     8           spread_lag_2           spread_lag_3              1.110114             0.365696  cross_lag_1   global_level                     spread|spread global|global
#     9           spread_lag_0           spread_lag_1              1.109039             0.365522  cross_lag_1   global_level                     spread|spread global|global
#    10           asks_0_lag_2           asks_0_lag_3              1.096897             0.442785  cross_lag_1     same_level                         asks|asks       ask|ask
#
# --- lag_10 ---
#  rank          source        target  abs_precision_weight  partial_corr_weight lag_relation level_relation   feature_pair     side_pair
#     1 mid_price_lag_0  bidp_9_lag_1              2.188716             0.785203  cross_lag_1   global_level bidp|mid_price    bid|global
#     2    asks_0_lag_0  asks_0_lag_1              1.058930             0.419792  cross_lag_1     same_level      asks|asks       ask|ask
#     3    asks_0_lag_9 asks_0_lag_10              1.058865             0.419660  cross_lag_1     same_level      asks|asks       ask|ask
#     4    bids_1_lag_0  bids_1_lag_1              1.022224             0.404581  cross_lag_1     same_level      bids|bids       bid|bid
#     5    bids_1_lag_9 bids_1_lag_10              1.019630             0.404134  cross_lag_1     same_level      bids|bids       bid|bid
#     6    bids_0_lag_9 bids_0_lag_10              1.017186             0.287464  cross_lag_1     same_level      bids|bids       bid|bid
#     7    bids_0_lag_0  bids_0_lag_1              1.007597             0.283956  cross_lag_1     same_level      bids|bids       bid|bid
#     8    spread_lag_9 spread_lag_10              0.959442             0.300846  cross_lag_1   global_level  spread|spread global|global
#     9    spread_lag_0  spread_lag_1              0.957614             0.300249  cross_lag_1   global_level  spread|spread global|global
#    10    bids_2_lag_0  bids_2_lag_1              0.901021             0.415818  cross_lag_1     same_level      bids|bids       bid|bid
#
# --- lag_20 ---
#  rank          source        target  abs_precision_weight  partial_corr_weight lag_relation level_relation   feature_pair     side_pair
#     1 mid_price_lag_0  bidp_9_lag_1              2.186626             0.783987  cross_lag_1   global_level bidp|mid_price    bid|global
#     2   asks_0_lag_19 asks_0_lag_20              1.058974             0.419524  cross_lag_1     same_level      asks|asks       ask|ask
#     3    asks_0_lag_0  asks_0_lag_1              1.058728             0.419346  cross_lag_1     same_level      asks|asks       ask|ask
#     4    bids_1_lag_0  bids_1_lag_1              1.018659             0.402463  cross_lag_1     same_level      bids|bids       bid|bid
#     5   bids_1_lag_19 bids_1_lag_20              1.018082             0.403461  cross_lag_1     same_level      bids|bids       bid|bid
#     6    bids_0_lag_0  bids_0_lag_1              1.010897             0.284941  cross_lag_1     same_level      bids|bids       bid|bid
#     7   bids_0_lag_19 bids_0_lag_20              1.007515             0.283809  cross_lag_1     same_level      bids|bids       bid|bid
#     8    spread_lag_0  spread_lag_1              0.958269             0.300270  cross_lag_1   global_level  spread|spread global|global
#     9   spread_lag_19 spread_lag_20              0.951759             0.298656  cross_lag_1   global_level  spread|spread global|global
#    10    bids_2_lag_0  bids_2_lag_1              0.901044             0.415839  cross_lag_1     same_level      bids|bids       bid|bid
#
# ----------------------------------------------------------------------------------------------------
# 9) TOP INTRA-LAG EDGES BY RUN
# ----------------------------------------------------------------------------------------------------
#
# --- lag_3 ---
#  rank                source                 target  abs_precision_weight  partial_corr_weight lag_relation level_relation                     feature_pair  side_pair
#     1 depth_ask_total_lag_3 global_imbalance_lag_3              0.224115            -0.066969    intra_lag   global_level depth_ask_total|global_imbalance ask|global
#     2 depth_ask_total_lag_0 global_imbalance_lag_0              0.220823            -0.065854    intra_lag   global_level depth_ask_total|global_imbalance ask|global
#     3 depth_ask_total_lag_2 global_imbalance_lag_2              0.204715            -0.058083    intra_lag   global_level depth_ask_total|global_imbalance ask|global
#     4 depth_ask_total_lag_1 global_imbalance_lag_1              0.202723            -0.057550    intra_lag   global_level depth_ask_total|global_imbalance ask|global
#     5 depth_bid_total_lag_3 global_imbalance_lag_3              0.185523             0.054204    intra_lag   global_level depth_bid_total|global_imbalance bid|global
#     6 depth_bid_total_lag_0 global_imbalance_lag_0              0.185401             0.054158    intra_lag   global_level depth_bid_total|global_imbalance bid|global
#     7 depth_bid_total_lag_2 global_imbalance_lag_2              0.171883             0.047962    intra_lag   global_level depth_bid_total|global_imbalance bid|global
#     8 depth_bid_total_lag_1 global_imbalance_lag_1              0.170963             0.047768    intra_lag   global_level depth_bid_total|global_imbalance bid|global
#     9          asks_9_lag_0  depth_ask_total_lag_0              0.111557             0.051570    intra_lag   global_level             asks|depth_ask_total    ask|ask
#    10          asks_9_lag_3  depth_ask_total_lag_3              0.111106             0.051458    intra_lag   global_level             asks|depth_ask_total    ask|ask
#
# --- lag_10 ---
#  rank                 source                  target  abs_precision_weight  partial_corr_weight lag_relation level_relation                     feature_pair  side_pair
#     1  depth_ask_total_lag_0  global_imbalance_lag_0              0.124823            -0.034667    intra_lag   global_level depth_ask_total|global_imbalance ask|global
#     2 depth_ask_total_lag_10 global_imbalance_lag_10              0.121128            -0.033634    intra_lag   global_level depth_ask_total|global_imbalance ask|global
#     3  depth_ask_total_lag_1  global_imbalance_lag_1              0.103538            -0.027319    intra_lag   global_level depth_ask_total|global_imbalance ask|global
#     4  depth_ask_total_lag_9  global_imbalance_lag_9              0.102591            -0.027136    intra_lag   global_level depth_ask_total|global_imbalance ask|global
#     5 depth_bid_total_lag_10 global_imbalance_lag_10              0.101221             0.027396    intra_lag   global_level depth_bid_total|global_imbalance bid|global
#     6  depth_bid_total_lag_0  global_imbalance_lag_0              0.098396             0.026588    intra_lag   global_level depth_bid_total|global_imbalance bid|global
#     7  depth_ask_total_lag_2  global_imbalance_lag_2              0.092399            -0.023802    intra_lag   global_level depth_ask_total|global_imbalance ask|global
#     8  depth_ask_total_lag_8  global_imbalance_lag_8              0.091853            -0.023661    intra_lag   global_level depth_ask_total|global_imbalance ask|global
#     9  depth_bid_total_lag_1  global_imbalance_lag_1              0.090791             0.023495    intra_lag   global_level depth_bid_total|global_imbalance bid|global
#    10  depth_ask_total_lag_3  global_imbalance_lag_3              0.087056            -0.022270    intra_lag   global_level depth_ask_total|global_imbalance ask|global
#
# --- lag_20 ---
#  rank                 source                  target  abs_precision_weight  partial_corr_weight lag_relation level_relation                     feature_pair  side_pair
#     1  depth_ask_total_lag_0  global_imbalance_lag_0              0.095945            -0.026460    intra_lag   global_level depth_ask_total|global_imbalance ask|global
#     2 depth_ask_total_lag_20 global_imbalance_lag_20              0.094601            -0.026020    intra_lag   global_level depth_ask_total|global_imbalance ask|global
#     3 depth_bid_total_lag_20 global_imbalance_lag_20              0.081459             0.021893    intra_lag   global_level depth_bid_total|global_imbalance bid|global
#     4  depth_bid_total_lag_0  global_imbalance_lag_0              0.081256             0.021841    intra_lag   global_level depth_bid_total|global_imbalance bid|global
#     5           asks_9_lag_0   depth_ask_total_lag_0              0.079257             0.034762    intra_lag   global_level             asks|depth_ask_total    ask|ask
#     6          asks_9_lag_20  depth_ask_total_lag_20              0.078611             0.034388    intra_lag   global_level             asks|depth_ask_total    ask|ask
#     7  depth_ask_total_lag_1  global_imbalance_lag_1              0.078220            -0.020534    intra_lag   global_level depth_ask_total|global_imbalance ask|global
#     8 depth_ask_total_lag_19 global_imbalance_lag_19              0.077965            -0.020441    intra_lag   global_level depth_ask_total|global_imbalance ask|global
#     9 depth_ask_total_lag_18 global_imbalance_lag_18              0.075653            -0.019486    intra_lag   global_level depth_ask_total|global_imbalance ask|global
#    10  depth_ask_total_lag_2  global_imbalance_lag_2              0.067075            -0.017205    intra_lag   global_level depth_ask_total|global_imbalance ask|global
#
# ----------------------------------------------------------------------------------------------------
# 10) COMPACT AUTOMATIC INTERPRETATION
# ----------------------------------------------------------------------------------------------------
# - Fastest run              : lag_3 (0.95 sec)
# - Most connected graph     : lag_20 (5419 edges)
# - Strongest temporal graph : lag_20 (cross-lag share=0.9210)
# - Most global-driven graph : lag_3 (global-level share=0.7150)
# - Most local-level graph   : lag_20 (same-level share=0.4877)
#
# Suggested reading:
# - lag_3  : compact baseline, easier to interpret
# - lag_10 : balanced compromise between temporal richness and readability
# - lag_20 : long-memory experiment, richer but more autoregressive and heavier
#
# ====================================================================================================
# END OF COMPARISON REPORT
# ====================================================================================================
